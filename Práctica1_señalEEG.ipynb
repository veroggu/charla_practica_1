# %% [markdown]
# <a href="https://colab.research.google.com/github/veroggu/charla_practica_1/blob/master/Pr%C3%A1ctica1_se%C3%B1alEEG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Explorando la señal EEG
# ![Oficiallogo png.png](`data:image/png;base64,...`)

# %% [markdown]
# ### **Identificación de la señal EEG**
# #### **Contexto**:
# ##### Con la representación de una señal EEG en el tiempo se puede observar niveles de potencial eléctrico a medida que ocurren cambios temporales.
#
# #### **Objetivo**
# ##### Graficar una señal EEG en el tiempo
#
# #### **Instrucciones**
# ##### Con el siguientes código se pretende importar una señal EEG de una paciente en estado de reposo y graficarla en el tiempo. La preguntas están orientadas a identificar algunas características de la señal para entender con qué información se está trabajando en cada momento.
#
#
# #### ***Google Forms: https://forms.gle/n2yz4qcu1H2wMUiP7***

# %% [markdown]
# ### -) Importación de librerías

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) -> Consulte cómo importar un archivo .mat con la librería Scipy de Python

import scipy.?? as --
data = --.load--("url") -> # (RESPUESTA 1) #

# %% [markdown]
# ### -) Datos EEG

# %%
# 2) -> A partir del archivo importado obtenga la información EEG para graficar (Clave = fijarse en que la variable <data> está es un diccionario)

data_eeg = data--

# (RESPUESTA 2) #

# %% [markdown]
# ### -) Información de la señal EEG importada

# %%
# Datos de la señal, frecuencia de muestreo y cantidad de datos totales:

frec_muestreo = 250
len_data = len(data_eeg) # ->Note que debe hacer una modificación

# %% [markdown]
# ### -) Vector de tiempo

# %%
# --- Contexto --> La frecuencia de muestreo da idea de la cantidad de valores que se obtienen en un segundo de toma de datos

# 3) -> Genere un vector de tiempo a partir de la frecuencia de muestreo (250 Hz) de la señal EEG

tiempo = ??/??    # (RESPUESTA 3) #

# Nota -> halle una relación la cantidad total de datos obtenidos

# %% [markdown]
# ### -) Graficación de la señal EEG

# %%
# tiempo = ??/??
time = np.linspace(0,tiempo,len_data);
plt.plot(time,data_eeg)

# %% [markdown]
# ### -) Etiquetas de ejes y título

# %%
plt.title('Señal EEG en el tiempo') 
plt.xlabel(??)
plt.ylabel(??)

# (RESPUESTA 4) #
